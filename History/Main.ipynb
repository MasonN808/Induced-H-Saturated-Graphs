# %%
H=Graph({0:[1,2,3]});H
# Out:
# Graph on 4 vertices

# %%
graphcycle(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d9a03ad4ccd3> in <module>
# ----> 1 graphcycle(Integer(6))
#
# NameError: name 'graphcycle' is not defined

# %%
g2=Graph({0:[1,6,11],1:[0,11,2,3],2:[8,3],3:[4,5],4:[10,5],5:[6,7],6:[7],7:[8,9],8:[9],9:[10,11],10:[11]});g2
# Out:
# Graph on 12 vertices

# %%
if g2.subgraph_search(H,induced=True):
        print ("True")
else:
            print ("False")
# Out:
# True

# %%
g2.add_edge(0,2);g2.show()
# Out:
# Graphics object consisting of 35 graphics primitives

# %%
if g2.subgraph_search(H,induced=True):
        print ("True")
else:
            print ("False")
# Out:
# True

# %%
g2.delete_edge(0,2);g2.show()
# Out:
# Graphics object consisting of 34 graphics primitives

# %%
if g2.subgraph_search(H,induced=True):
        print ("True")
else:
            print ("False")
# Out:
# True

# %%
g3=g2.complement()

# %%
g4=CompleteGraph(24)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0e6fb21c4c8c> in <module>
# ----> 1 g4=CompleteGraph(Integer(24))
#
# NameError: name 'CompleteGraph' is not defined

# %%
g2=Graph({0:[1,6,11],1:[0,11,2,3],2:[8,3],3:[4,5],4:[10,5],5:[6,7],6:[7],7:[8,9],8:[9],9:[10,11],10:[11]});g2.show()
# Out:
#   File "<ipython-input-2-5a05d62968ee>", line 2
#     for i in [Integer(1),Integer(2),Integer(3),Integer(4),Integer(5),Integer(6)] and i' in [1,2,3,4,5,6]:
#                                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
g2=Graph({0:[1,6,11],1:[0,11,2,3],2:[8,3],3:[4,5],4:[10,5],5:[6,7],6:[7],7:[8,9],8:[9],9:[10,11],10:[11]});
g3=g2.Complement()
edges=g3.edges
for (i,x) in [(1,2),(2,3),(4,5)]:
 if i!=x:
    print((i,x))
# Out:
# (1, 2)
# (2, 3)
# (4, 5)

# %%
g2=Graph({0:[1,6,11],1:[0,11,2,3],2:[8,3],3:[4,5],4:[10,5],5:[6,7],6:[7],7:[8,9],8:[9],9:[10,11],10:[11]});
g3=g2.complement();
edges=g3.edges();
edges
# Out:
# [(0, 2, None), (0, 3, None), (0, 4, None), (0, 5, None), (0, 7, None), (0, 8, None), (0, 9, None), (0, 10, None), (1, 4, None), (1, 5, None), (1, 6, None), (1, 7, None), (1, 8, None), (1, 9, None), (1, 10, None), (2, 4, None), (2, 5, None), (2, 6, None), (2, 7, None), (2, 9, None), (2, 10, None), (2, 11, None), (3, 6, None), (3, 7, None), (3, 8, None), (3, 9, None), (3, 10, None), (3, 11, None), (4, 6, None), (4, 7, None), (4, 8, None), (4, 9, None), (4, 11, None), (5, 8, None), (5, 9, None), (5, 10, None), (5, 11, None), (6, 8, None), (6, 9, None), (6, 10, None), (6, 11, None), (7, 10, None), (7, 11, None), (8, 10, None), (8, 11, None)]

# %%
H=Graph({0:[1,2,3]});
g2=Graph({0:[1,6,11],1:[0,11,2,3],2:[8,3],3:[4,5],4:[10,5],5:[6,7],6:[7],7:[8,9],8:[9],9:[10,11],10:[11]});
for (x,y) in [(0, 2), (0, 3), (0, 4), (0, 5), (0, 7), (0, 8), (0, 9), (0, 10), (1, 4,), (1, 5), (1, 6), (1, 7), (1, 8), (1, 9), (1, 10), (2, 4), (2, 5), (2, 6), (2, 7)]:
    if x!=y:
        g5=g2.add_edge(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-71c0258780a0> in <module>
#       4     if x!=y:
#       5         g5=g2.add_edge(x,y)
# ----> 6         g5.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'

# %%
if g5.subgraph_search(H,induced=True)==True:
        print ((x,y),"True")
    else:
            print ((x,y),"False")
